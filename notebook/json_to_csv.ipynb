# %%
import requests

url = "https://api.coincap.io/v2/assets"

payload = ""
headers = {"Authorization": "Bearer 0152edfe-a10f-4bf8-9b0d-c266473edcec"}

response = requests.request("GET", url, data=payload, headers=headers)

data = response.json()

# %% [markdown]
# # JSON to CSV

# %%
import pandas as pd

df = pd.DataFrame.from_dict(data['data'])
df.to_csv("bitcoin.csv", sep="|", index=False)
df
# Out:
#               id rank symbol          name                        supply  \
# 0        bitcoin    1    BTC       Bitcoin     19196056.0000000000000000
# 1       ethereum    2    ETH      Ethereum    122373863.4990000000000000
# 2         tether    3   USDT        Tether  69419933938.3116100000000000
# 3   binance-coin    4    BNB           BNB    166801148.0000000000000000
# 4       usd-coin    5   USDC      USD Coin  43035277448.5961100000000000
# ..           ...  ...    ...           ...                           ...
# 95       arweave   96     AR       Arweave     33394701.0000000000000000
# 96          celo   97   CELO          Celo    473376178.0000000000000000
# 97    theta-fuel   98  TFUEL    Theta Fuel   5301214400.0000000000000000
# 98     defichain   99    DFI     DeFiChain    510738160.8525277400000000
# 99  bitcoin-gold  100    BTG  Bitcoin Gold     17513923.5890000000000000
#
#                       maxSupply                   marketCapUsd  \
# 0     21000000.0000000000000000  392967983155.1963300509370024
# 1                          None  191969819914.3042981971912403
# 2                          None   69352848877.6756507553637948
# 3    166801148.0000000000000000   53486980837.2717688999022328
# 4                          None   42986647581.1648840036132371
# ..                          ...                            ...
# 95    66000000.0000000000000000     339614469.0197730334564782
# 96  1000000000.0000000000000000     337122776.1453464384994962
# 97                         None     316948069.1931339486222400
# 98  1200000000.0000000000000000     316365881.9439154470476118
# 99    21000000.0000000000000000     311075800.1124894460889863
#
#                    volumeUsd24Hr                priceUsd    changePercent24Hr  \
# 0   10732096633.4792043439950198  20471.2875996609058679  -0.4081201083040659
# 1    4709335947.9398505129211719   1568.7158550475364705  -1.3906674149960992
# 2   18716665530.5159433762284968      0.9990336340467340   0.0832864482280882
# 3     409466276.4698436480143475    320.6631457792590786  -2.0751079672227373
# 4    1122034552.5192149347747787      0.9988699999090441   0.0160075361545221
# ..                           ...                     ...                  ...
# 95      9771224.7226288417060686     10.1697113269489382  -1.2253094616070073
# 96      3890113.9285169195303817      0.7121667540806129  -4.2002283853274132
# 97     10443412.6262777445313989      0.0597878231812571  -2.0423934273867779
# 98       638259.0852412212265744      0.6194287135620242  -4.2183169059127802
# 99      8788150.0144102348715137     17.7616282571808956  -0.1496951402131053
#
#                   vwap24Hr                                           explorer
# 0   20493.3894623382545555                           https://blockchain.info/
# 1    1580.8003943600022870                              https://etherscan.io/
# 2       0.9980261800658721             https://www.omniexplorer.info/asset/31
# 3     322.8965909550140154  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4       0.9991480098154532  https://etherscan.io/token/0xa0b86991c6218b36c...
# ..                     ...                                                ...
# 95     10.1872413763801860                       https://viewblock.io/arweave
# 96      0.7231943217513045                   https://explorer.celo.org/blocks
# 97      0.0611824553300556                   https://explorer.thetatoken.org/
# 98      0.6464800420398165                      http://explorer.defichain.io/
# 99     16.8687339487216756          https://explorer.bitcoingold.org/insight/
#
# [100 rows x 12 columns]
